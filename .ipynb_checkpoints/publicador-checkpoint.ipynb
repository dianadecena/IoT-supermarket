# %% [markdown]
# # publicador

# %%
import ssl
import sys
import json
import random
import time
import paho.mqtt.client
import paho.mqtt.publish
import numpy as np
import datetime
import psycopg2
import threading
import pub

# %% [markdown]
# # conexión con la base de datos

# %%
host='echo.db.elephantsql.com'
user ='nvcmxuqc'
password='Zb2xa6xreimFVSFt5uXM_F_TBCQBzy3l'
dbname='nvcmxuqc'

# %%
connection = psycopg2.connect(host = host,
                                user= user, password =password,
                                dbname= dbname)

# %% [markdown]
# # iniciar simulación

# %%
##se crea un publicador y se conecta 
pub_estante = pub.publicador(connection, 'Automercados Plaza')
pub_estante.conectar_dispositivo()

##el publicador también será suscriptor de un canal por lo que se necesitan dos hilos para ejecutar 
##esos procesos paralelamente 
sub_t = threading.Thread(target=pub_estante.conectar_suscriptor)
pub_t = threading.Thread(target=pub_estante.iniciar_sucursal)

##iniciar hilos 
sub_t.start()
pub_t.start()
# Out:
# Cliente id: 25  Indice:  24
# Indices: [24, 39, 42, 33, 6, 30, 4, 43]
# se ha suscrito correctamente (b'')
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Pan Integral',)
# El cliente agarra 2 de este producto
# El cliente lo compra
# {'id_producto': 9, 'cantidad': 2, 'id_estante': 3, 'sucursal': 'sucursal1', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 40  Indice:  39
# Indices: [24, 39, 42, 33, 6, 30, 4, 43]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 40, 'id_sucursal': 1}
# El cliente sigue viendo
# Cliente id: 43  Indice:  42
# Indices: [24, 39, 42, 33, 6, 30, 4, 43]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Crema de Leche',)
# El cliente agarra 7 de este producto
# El cliente lo deja
# El cliente se va
# Cliente id: 7  Indice:  6
# Indices: [24, 39, 33, 6, 30, 4, 43]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (11,)
# El cliente elige el producto: ('Sal',)
# El cliente agarra 7 de este producto
# El cliente lo compra
# {'id_producto': 30, 'cantidad': 7, 'id_estante': 11, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente va a pagar
# El total a pagar es: 196
# Cliente id: 31  Indice:  30
# Indices: [24, 39, 33, 6, 30, 4, 43]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (12,)
# El cliente elige el producto: ('Arroz',)
# El cliente agarra 6 de este producto
# El cliente lo deja
# El cliente se va
# Cliente id: 44  Indice:  43
# Indices: [24, 39, 33, 6, 4, 43]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Patilla',)
# El cliente agarra 70 de este producto
# El cliente lo deja
# El cliente sigue viendo
# entran más clientes
# Cantidad: 6
# Entran los siguientes indices de clientes: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 29, 7]
# Cliente id: 35  Indice:  34
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 29, 7]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 35, 'id_sucursal': 2}
# El cliente sigue viendo
# Cliente id: 32  Indice:  31
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 29, 7]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (12,)
# El cliente elige el producto: ('Arroz',)
# El cliente agarra 51 de este producto
# El cliente lo compra
# {'id_producto': 34, 'cantidad': 51, 'id_estante': 12, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente va a pagar
# El total a pagar es: 1224
# Cliente id: 42  Indice:  41
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 29, 7]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (7,)
# El cliente elige el producto: ('Sopa',)
# El cliente agarra 2 de este producto
# El cliente lo compra
# {'id_producto': 28, 'cantidad': 2, 'id_estante': 7, 'sucursal': 'sucursal1', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 41  Indice:  40
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 29, 7]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 41, 'id_sucursal': 2}
# El cliente sigue viendo
# Cliente id: 30  Indice:  29
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 29, 7]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 30, 'id_sucursal': 1}
# El cliente se va
# Cliente id: 25  Indice:  24
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (1,)
# El cliente elige el producto: ('Leche',)
# El cliente agarra 4 de este producto
# El cliente lo compra
# {'id_producto': 1, 'cantidad': 4, 'id_estante': 1, 'sucursal': 'sucursal1', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 40  Indice:  39
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (4,)
# El cliente elige el producto: ('Jugo de Manzana',)
# El cliente agarra 10 de este producto
# El cliente lo compra
# {'id_producto': 11, 'cantidad': 10, 'id_estante': 4, 'sucursal': 'sucursal1', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente va a pagar
# El total a pagar es: 200
# Cliente id: 34  Indice:  33
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 34, 'id_sucursal': 2}
# El cliente sigue viendo
# Cliente id: 7  Indice:  6
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (10,)
# El cliente elige el producto: ('Jamón',)
# El cliente agarra 11 de este producto
# El cliente lo compra
# {'id_producto': 21, 'cantidad': 11, 'id_estante': 10, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente va a pagar
# El total a pagar es: 251
# Cliente id: 5  Indice:  4
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (13,)
# El cliente elige el producto: ('Zanahoria',)
# El cliente agarra 76 de este producto
# El cliente lo compra
# {'id_producto': 36, 'cantidad': 76, 'id_estante': 13, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 44  Indice:  43
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (11,)
# El cliente elige el producto: ('Harina',)
# El cliente agarra 2 de este producto
# El cliente lo compra
# {'id_producto': 32, 'cantidad': 2, 'id_estante': 11, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 35  Indice:  34
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (11,)
# El cliente elige el producto: ('Harina',)
# El cliente agarra 18 de este producto
# El cliente lo deja
# El cliente sigue viendo
# Cliente id: 32  Indice:  31
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (10,)
# El cliente elige el producto: ('Chorizo',)
# El cliente agarra 63 de este producto
# El cliente lo compra
# {'id_producto': 19, 'cantidad': 63, 'id_estante': 10, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 42  Indice:  41
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Crema de Leche',)
# El cliente agarra 1 de este producto
# El cliente lo compra
# {'id_producto': 7, 'cantidad': 1, 'id_estante': 3, 'sucursal': 'sucursal1', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 41  Indice:  40
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 40, 7]
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (9,)
# El cliente elige el producto: ('Galletas de Avena',)
# El cliente agarra 10 de este producto
# El cliente lo deja
# El cliente se va
# Cliente id: 25  Indice:  24
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (7,)
# El cliente elige el producto: ('Salsa de Tomate',)
# El cliente agarra 9 de este producto
# El cliente lo compra
# {'id_producto': 27, 'cantidad': 9, 'id_estante': 7, 'sucursal': 'sucursal1', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente va a pagar
# El total a pagar es: 413
# Cliente id: 40  Indice:  39
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Crema de Leche',)
# El cliente agarra 6 de este producto
# El cliente lo compra
# {'id_producto': 7, 'cantidad': 6, 'id_estante': 3, 'sucursal': 'sucursal1', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente va a pagar
# El total a pagar es: 314
# Cliente id: 34  Indice:  33
# Indices: [24, 39, 33, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (9,)
# El cliente elige el producto: ('Galletas de Avena',)
# El cliente agarra 21 de este producto
# El cliente lo deja
# El cliente se va
# Cliente id: 5  Indice:  4
# Indices: [24, 39, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Fresas',)
# El cliente agarra 29 de este producto
# El cliente lo compra
# {'id_producto': 40, 'cantidad': 29, 'id_estante': 14, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 44  Indice:  43
# Indices: [24, 39, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Fresas',)
# El cliente agarra 77 de este producto
# El cliente lo deja
# El cliente va a pagar
# El total a pagar es: 18
# Cliente id: 35  Indice:  34
# Indices: [24, 39, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (12,)
# El cliente elige el producto: ('Arroz',)
# El cliente agarra 25 de este producto
# El cliente lo compra
# {'id_producto': 34, 'cantidad': 25, 'id_estante': 12, 'sucursal': 'sucursal2', 'hora': '2020-06-21 22:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 32  Indice:  31
# Indices: [24, 39, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Fresas',)
# El cliente agarra 84 de este producto
# El cliente lo deja
# El cliente sigue viendo
# Cliente id: 42  Indice:  41
# Indices: [24, 39, 6, 4, 43, 34, 31, 41, 7]
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (7,)
# El cliente elige el producto: ('Salsa de Tomate',)
# El cliente agarra 1 de este producto
# El cliente lo deja
# El cliente va a pagar
# El total a pagar es: 105
# Cliente id: 8  Indice:  7
# Indices: [24, 39, 6, 4, 43, 34, 31, 41, 7]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 5
# El cliente se dirige al estante (16,)
# El cliente elige el producto: ('Limón',)
# El cliente agarra 106 de este producto
# El cliente lo deja
# El cliente se va
# pues no mi ciela
# Cliente id: 25  Indice:  24
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Pan de Trigo',)
# El cliente agarra 15 de este producto
# El cliente lo deja
# El cliente sigue viendo
# Cliente id: 40  Indice:  39
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (5,)
# El cliente elige el producto: ('Golden Naranja',)
# El cliente agarra 4 de este producto
# El cliente lo compra
# {'id_producto': 15, 'cantidad': 4, 'id_estante': 5, 'sucursal': 'sucursal1', 'hora': '2020-06-22 00:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 7  Indice:  6
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (10,)
# El cliente elige el producto: ('Jamón',)
# El cliente agarra 8 de este producto
# El cliente lo deja
# El cliente va a pagar
# El total a pagar es: 251
# Cliente id: 5  Indice:  4
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (11,)
# El cliente elige el producto: ('Sal',)
# El cliente agarra 23 de este producto
# El cliente lo compra
# {'id_producto': 30, 'cantidad': 23, 'id_estante': 11, 'sucursal': 'sucursal2', 'hora': '2020-06-22 02:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 44  Indice:  43
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (12,)
# El cliente elige el producto: ('Leche en Polvo',)
# El cliente agarra 13 de este producto
# El cliente lo compra
# {'id_producto': 35, 'cantidad': 13, 'id_estante': 12, 'sucursal': 'sucursal2', 'hora': '2020-06-22 03:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 35  Indice:  34
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Patilla',)
# El cliente agarra 68 de este producto
# El cliente lo compra
# {'id_producto': 41, 'cantidad': 68, 'id_estante': 14, 'sucursal': 'sucursal2', 'hora': '2020-06-22 04:00:00.073816'}
# El cliente sigue viendo
# Cliente id: 32  Indice:  31
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Patilla',)
# El cliente agarra 8 de este producto
# El cliente lo compra
# {'id_producto': 41, 'cantidad': 8, 'id_estante': 14, 'sucursal': 'sucursal2', 'hora': '2020-06-22 05:00:00.073816'}
# El cliente va a pagar
# El total a pagar es: 3377
# Cliente id: 42  Indice:  41
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (1,)
# El cliente elige el producto: ('Mantequilla',)
# El cliente agarra 8 de este producto
# El cliente lo deja
# El cliente sigue viendo
# pues no mi ciela
# Cliente id: 25  Indice:  24
# Indices: [24, 39, 6, 4, 43, 34, 31, 41]
# El cliente se dirige al pasillo 5
# El cliente se dirige al estante (8,)
# El cliente elige el producto: ('Oreo',)
# El cliente agarra 5 de este producto
# El cliente lo deja
# El cliente va a pagar
# El total a pagar es: 413
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ramon Decena\Proyecto 1 Final\pub.py", line 457, in iniciar_sucursal
#     cur.execute("SELECT realizar_pago(%s, (SELECT no_cuenta FROM cuenta_programa_fidelidad WHERE id_cliente = %s), %s, %s, %s, %s, %s, %s, %s)", (clientes[i]["id_cliente"],clientes[i]["id_cliente"],banco,sucursal,cont_factura,total,0,total,hora,))
# psycopg2.errors.ForeignKeyViolation: insert or update on table "factura" violates foreign key constraint "factura_id_cliente_fkey"
# DETAIL:  Key (id_cliente)=(26) is not present in table "cliente".
# CONTEXT:  SQL statement "INSERT into factura (id_factura, id_cliente, fecha_hora, banco, id_sucursal, total, descuento, total_pago) VALUES
#         (id_factura, id_cliente, fecha_hora, banco, id_sucursal, total, descuento, total_pago)"
# PL/pgSQL function realizar_pago(integer,integer,character varying,integer,integer,numeric,numeric,numeric,timestamp without time zone) line 3 at SQL statement
